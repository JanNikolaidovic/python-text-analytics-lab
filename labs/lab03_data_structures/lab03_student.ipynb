# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JanNikolaidovic/python-text-analytics-lab/blob/main/labs/lab03_data_structures/lab03_student.ipynb)

# %% [markdown]
# # Lab 03 — Data Structures & Control Flow
#
# ### Python for Text Analytics

# %%
#test
print(2)
