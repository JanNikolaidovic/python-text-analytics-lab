# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JanNikolaidovic/python-text-analytics-lab/blob/main/labs/lab02_variables_data_types/lab02_student.ipynb)

# %% [markdown]
# # Lab 02 — Variables & Simple Data Types
#
# ### Python for Text Analytics
