# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JanNikolaidovic/python-text-analytics-lab/blob/main/labs/lab02_data_structures/lab02_student.ipynb)

# %% [markdown]
# # Lab 02 — Data Structures & Control Flow
#
# ### Python for Text Analytics
